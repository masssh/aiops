# %% [markdown]
# # GitHub Agent - Interactive Notebook
#
# このnotebookでは、github_agentをインタラクティブに実行できます。

# %%
# セットアップ
import sys
import os
import yaml
sys.path.append('..')

from src.agents.github_agent import github_agent
from src.models.state import OverallState
from langchain_core.runnables import RunnableConfig
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
# products.yamlをプロジェクトルートから読み込む
products_yaml_path = "../products.yaml"

if os.path.exists(products_yaml_path):
    with open(products_yaml_path, 'r', encoding='utf-8') as f:
        products_config = yaml.safe_load(f)
    print(f"✅ products.yaml を読み込みました")
    print(f"リポジトリ数: {len(products_config.get('repositories', []))}")
    for repo in products_config.get('repositories', []):
        print(f"  - {repo.get('id')}: {repo.get('name')}")
else:
    print(f"⚠️ products.yaml が見つかりません: {products_yaml_path}")
    products_config = {"repositories": [], "products": []}

# 初期状態（products.yamlから読み込んだ設定を使用）
state: OverallState = {
    "products_config": products_config,
    "results": {}
}
# Out:
# ✅ products.yaml を読み込みました
# リポジトリ数: 1
#   - springboot-microservices: Gradle Project Sample

# %%
# 設定: LLMプロバイダーとモデルを選択
PROVIDER = "ollama"  # "gemini", "openai", "anthropic", "ollama" から選択
MODEL = "qwen3:8b"   # プロバイダーごとのモデル名（Noneでデフォルト使用）
MAX_ITERATIONS = 20  # エージェントの最大反復回数

# %%
PROMPT = """
リポジトリ springboot-microservices をcloneして
"""

config = RunnableConfig(
    configurable={
        "provider": PROVIDER,
        "model": MODEL,
        "project_root": "../",
        "github_agent_prompt": PROMPT,
        "max_iterations": MAX_ITERATIONS
    }
)

result = github_agent(state, config)
print("\n=== 実行完了! ===")
# Out:
# 15:13:12 - INFO - github_agent logger initialized. Log file: logs/github_agent_20260214_151312.log
# 15:13:12 - INFO - ================================================================================
# 15:13:12 - INFO - GitHub Agent started
# 15:13:12 - INFO - Provider: ollama, Model: qwen3:8b
# 15:13:12 - INFO - Verbose: False
# 15:13:12 - INFO - Project root: ../
# 15:13:12 - INFO - Workspace directory: /Users/masssh/dev/aiops/workspace
# 15:13:12 - INFO - Max iterations: 20
# 15:13:12 - INFO - ================================================================================
# 15:13:12 - INFO - Using custom prompt:
# リポジトリ springboot-microservices をcloneして
# ...
# 15:13:12 - INFO -
# ================================================================================
# 15:13:12 - INFO - Iteration 1/20
# 15:13:12 - INFO - ================================================================================
# 15:14:34 - INFO - LLM decided to execute 1 tool(s):
# 15:14:34 - INFO -   1. gh_repo_clone
# 15:14:34 - INFO -
# --- Executing tool: gh_repo_clone ---
# 15:14:38 - INFO - Tool execution successful
# 15:14:38 - INFO -
# ================================================================================
# 15:14:38 - INFO - Iteration 2/20
# 15:14:38 - INFO - ================================================================================
# 15:15:43 - INFO - LLM has completed its task (no more tool calls)
# 15:15:43 - INFO - Final message: The repository `springboot-microservices` has been successfully cloned to the specified path:
# `/Users/masssh/dev/aiops/workspace/springboot-microservices`
#
# Would you like to perform any further actions (e.g., check status, create branches, or make changes)?
# 15:15:43 - INFO -
# ================================================================================
# 15:15:43 - INFO - GitHub Agent execution completed
# 15:15:43 - INFO - ================================================================================
# === 実行完了! ===
