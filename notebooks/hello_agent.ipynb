# %% [markdown]
# # Hello Agent - Interactive Notebook
#
# このnotebookでは、hello_agentをインタラクティブに実行できます。
#
# ## 機能
# - 異なるLLMプロバイダー（Gemini, OpenAI, Anthropic, Ollama）をテスト
# - カスタムプロンプトで実行

# %%
# セットアップ
import sys
sys.path.append('..')

from src.agents.hello_agent import hello_agent
from src.models.state import OverallState
from langchain_core.runnables import RunnableConfig
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
# 設定: LLMプロバイダーとモデルを選択
# PROVIDER = "ollama"
PROVIDER = "gemini"
# PROVIDER = "openai"
# PROVIDER = "anthropic"

# MODEL = "qwen3:8b"
MODEL = "gemini-flash-latest"

# 初期状態
state: OverallState = {
    "products_config": {},
    "results": {}
}

# 設定
config = RunnableConfig(
    configurable={
        "provider": PROVIDER,
        "model": MODEL
    }
)

# %%
# エージェントを実行
result = hello_agent(state, config)
print("\n実行完了!")
# Out:
# 20:57:44 - INFO - hello_agent logger initialized. Log file: logs/hello_agent_20260214_205744.log
# 20:57:44 - INFO - ================================================================================
# 20:57:44 - INFO - Hello Agent started
# 20:57:44 - INFO - Provider: gemini, Model: gemini-flash-latest
# 20:57:44 - INFO - Verbose: False
# 20:57:44 - INFO - Project root: /Users/masssh/dev/aiops/notebooks
# 20:57:44 - INFO - Workspace directory: /Users/masssh/dev/aiops/notebooks/workspace
# 20:57:44 - INFO - Max iterations: 20
# 20:57:44 - INFO - ================================================================================
# 20:57:44 - INFO - Using default prompt
# 20:57:45 - INFO -
# ================================================================================
# 20:57:45 - INFO - Iteration 1/20
# 20:57:45 - INFO - ================================================================================
# 20:57:48 - INFO - LLM has completed its task (no more tool calls)
# 20:57:48 - INFO - Final message: [{'type': 'text', 'text': "Hello World from Gemini Agent! It's a pleasure to meet you!", 'extras': {'signature': '...'}}]
# 20:57:48 - INFO -
# ================================================================================
# 20:57:48 - INFO - Hello Agent execution completed
# 20:57:48 - INFO - ================================================================================
#
# 実行完了!
