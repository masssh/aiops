# %% [markdown]
# # Hello Agent - Interactive Notebook
#
# このnotebookでは、hello_agentをインタラクティブに実行できます。
#
# ## 機能
# - 異なるLLMプロバイダー（Gemini, OpenAI, Anthropic, Ollama）をテスト
# - カスタムプロンプトで実行

# %%
# セットアップ
import sys
sys.path.append('..')

from src.agents.hello_agent import hello_agent
from src.models.state import OverallState
from langchain_core.runnables import RunnableConfig
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
# 設定: LLMプロバイダーとモデルを選択
# PROVIDER = "ollama"
PROVIDER = "gemini"
# PROVIDER = "openai"
# PROVIDER = "anthropic"

# MODEL = "qwen3:8b"
MODEL = "gemini-flash-latest"

# 初期状態
state: OverallState = {
    "products_config": {},
    "results": {}
}

# 設定
config = RunnableConfig(
    configurable={
        "provider": PROVIDER,
        "model": MODEL
    }
)

# %%
# エージェントを実行
result = hello_agent(state, config)
print("\n実行完了!")
# Out:
# 21:36:49 | INFO     | hello_agent logger initialized. Log file: logs/hello_agent_20260214_213649.log
# 21:36:49 | INFO     | ================================================================================
# 21:36:49 | INFO     | Hello Agent started
# 21:36:49 | INFO     | Provider: gemini, Model: gemini-flash-latest
# 21:36:49 | INFO     | Verbose: False
# 21:36:49 | INFO     | Project root: /Users/masssh/dev/aiops/notebooks
# 21:36:49 | INFO     | Workspace directory: /Users/masssh/dev/aiops/notebooks/workspace
# 21:36:49 | INFO     | Max iterations: 20
# 21:36:49 | INFO     | ================================================================================
# 21:36:49 | INFO     | Using default prompt
# 21:36:49 | INFO     | Full user prompt:
# Say 'Hello World from Gemini Agent!'
# 21:36:49 | INFO     |
# ================================================================================
# 21:36:49 | INFO     | Iteration 1/20
# 21:36:49 | INFO     | ================================================================================
# 21:36:49 | INFO     | Invoking LLM to determine next action...
# 21:36:51 | INFO     |
# --- Usage Metrics (Iteration 1) ---
#
# 実行完了!
# 21:36:51 | INFO     | LLM Call Tokens:
# 21:36:51 | INFO     |   Input Tokens:  49
# 21:36:51 | INFO     |   Output Tokens: 102
# 21:36:51 | INFO     |   Total Tokens:  151
# 21:36:51 | INFO     | Context Metrics:
# 21:36:51 | INFO     |   Total Messages: 3
# 21:36:51 | INFO     |   Total Characters: 946
# 21:36:51 | INFO     | Cumulative Totals:
# 21:36:51 | INFO     |   Total Input Tokens:  49
# 21:36:51 | INFO     |   Total Output Tokens: 102
# 21:36:51 | INFO     |   Grand Total Tokens:  151
# 21:36:51 | INFO     |   Total LLM Calls: 1
# 21:36:51 | INFO     | LLM response content: [{'type': 'text', 'text': "Hello World from Gemini Agent! It's a pleasure to meet you!", 'extras': {'signature': '...'}}]
# 21:36:51 | INFO     | LLM has completed its task (no more tool calls)
# 21:36:51 | INFO     | Final message: [{'type': 'text', 'text': "Hello World from Gemini Agent! It's a pleasure to meet you!", 'extras': {'signature': '...'}}]
# 21:36:51 | INFO     |
# ================================================================================
# 21:36:51 | INFO     | Hello Agent execution completed
